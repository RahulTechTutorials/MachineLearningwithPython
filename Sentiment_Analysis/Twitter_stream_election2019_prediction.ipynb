# %% [markdown]
# # Importing Libraries

# %%
import tweepy
from tweepy import OAuthHandler,Stream,API
from tweepy.streaming import StreamListener
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import re
import twitter_creds
from twitter_creds import *
import re
import json
from collections import Counter

# %% [markdown]
# # Function for api authentication

# %%
def Authentication() : 
    auth = OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN,ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    return api

# %% [markdown]
# # Function for creating a StreamListener

# %%
class MyStreamListener(StreamListener):
    def on_data(self,data):
        try:
            with open('tweet.json','a') as ff:
                ff.write(data)
            return True
        except BaseException as e:
            print("Error on data : %s" % str(e))
            return True
    def on_error(self,status):
        print(status)
        return True

# %%
api = Authentication()
ListenObj = MyStreamListener()
my_stream = Stream(api.auth,ListenObj)

# %%
my_stream.filter(track=['generalelections2019','2019elections','GeneralElections2019','LokSabhaElections2019','Elections2019'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# ...

# %%
tweets = []
for line in open('tweet.json', 'r'):
    tweets.append(json.loads(line))

# %%
tweets[7]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Apr 04 02:27:18 +0000 2019',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 44704537,
#     'id_str': '44704537',
#     'indices': [3, 16],
#     'name': 'Kanchan Gupta',
#     'screen_name': 'KanchanGupta'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1113629083902943232,
#  'id_str': '1113629083902943232',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'quoted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Apr 03 19:48:08 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
# ...

# %%
for rec in tweets:
    print(rec['created_at'])
    print(rec['user']['name'])
    print(rec['text'])
# Out:
# Thu Apr 04 02:27:11 +0000 2019
# Chowkidhar Dr srish
# RT @KanchanGupta: So it's official now. Abhijit Banerjee, who advised on Rs 72k handout, said taxes would go up. Now Sam Pitroda says taxes…
# Thu Apr 04 02:27:12 +0000 2019
# Shaswat
# RT @IndiaToday: I don’t need to make @narendramodi look like a hero. He is a hero, says @vivekoberoi
# Watch #Countdown with @sardesairajdeep…
# Thu Apr 04 02:27:15 +0000 2019
# Ajinkya Kulkarni
# RT @Dev_Fadnavis: Attended &amp; addressed a huge &amp; record breaking rally at Gondia for Bhandara-Gondia LokSabha, with our Hon PM @narendramodi…
# Thu Apr 04 02:27:16 +0000 2019
# राजेंद्र कुमार
# RT @Shazia: Hey Bhagwan/Ya Allah
#
# “Mujh par kar de Ek ehsan
# Mujhe bhi bana de aisa Kisaan🙏🏻”
#
# As of 2018,in Maharashtra alone, more than 6…
# Thu Apr 04 02:27:16 +0000 2019
# Nikhil Ranjan
# RT @ANI: #LokSabhaElections2019 : Election Commission of India has seized Rs 377.511 Crore cash, Rs 157 Crore worth liquor, Rs 705 Crore wo…
# ...

# %%
data['text']
# Out:
# 'RT @jigneshmevani80: Help me find a speech more powerful than this. @kanhaiyakumar \n\n#Kanhaiya4Begusarai #Elections2019 https://t.co/gNqxuj…'

# %%
data['created_at']
# Out:
# 'Thu Apr 04 00:58:10 +0000 2019'

# %%
data['retweeted_status']['user']['name']
# Out:
# 'Jignesh Mevani'
